# %% [markdown]
# # Preguntas
#
# ### ¿Cuál es la evolución anual de la cantidad de prisioneros en los países de cada continente?
# ### ¿Qué países tienen más prisioneros en el mundo?
# ### ¿Cuál es la tendencia anual de la cantidad de prisioneros en estos países?
# ### ¿Cuál es la distribución de prisioneros en las regiones de cada continente?
# ### ¿Cuál es el continente con más prisioneros a lo largo de los años?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

years = np.array(list(range(2004, 2018)))

prisonReport = pd.read_excel('prison_report.xlsx')
prisonReport.set_index('Region')
prisonReport = prisonReport.rename(columns={'Sub Region': 'Subregion'})
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017])

# %% [markdown]
# Primero separamos los datos de cada año y los ordenamos por el número de prisioneros:

# %%
#pr2004 = prisonReport.loc[prisonReport.index[0:], ['Countries', 'Year', 'Count']]
#pr2004[pr2004.Year == 2004]

pr2004 = prisonReport[prisonReport.Year == 2004]
pr2004 = pr2004.sort_values(by = 'Countries', ascending = True)
pr2004 = pr2004.set_index('Countries')

pr2005 = prisonReport[prisonReport.Year == 2005]
pr2005 = pr2005.sort_values(by = 'Countries', ascending = True)
pr2005 = pr2005.set_index('Countries')

pr2006 = prisonReport[prisonReport.Year == 2006]
pr2006 = pr2006.sort_values(by = 'Countries', ascending = True)
pr2006 = pr2006.set_index('Countries')

pr2007 = prisonReport[prisonReport.Year == 2007]
pr2007 = pr2007.sort_values(by = 'Countries', ascending = True)
pr2007 = pr2007.set_index('Countries')

pr2008 = prisonReport[prisonReport.Year == 2008]
pr2008 = pr2008.sort_values(by = 'Countries', ascending = True)
pr2008 = pr2008.set_index('Countries')

pr2009 = prisonReport[prisonReport.Year == 2009]
pr2009 = pr2009.sort_values(by = 'Countries', ascending = True)
pr2009 = pr2009.set_index('Countries')

pr2010 = prisonReport[prisonReport.Year == 2010]
pr2010 = pr2010.sort_values(by = 'Countries', ascending = True)
pr2010 = pr2010.set_index('Countries')

pr2011 = prisonReport[prisonReport.Year == 2011]
pr2011 = pr2011.sort_values(by = 'Countries', ascending = True)
pr2011 = pr2011.set_index('Countries')

pr2012 = prisonReport[prisonReport.Year == 2012]
pr2012 = pr2012.sort_values(by = 'Countries', ascending = True)
pr2012 = pr2012.set_index('Countries')

pr2013 = prisonReport[prisonReport.Year == 2013]
pr2013 = pr2013.sort_values(by = 'Countries', ascending = True)
pr2013 = pr2013.set_index('Countries')

pr2014 = prisonReport[prisonReport.Year == 2014]
pr2014 = pr2014.sort_values(by = 'Countries', ascending = True)
pr2014 = pr2014.set_index('Countries')

pr2015 = prisonReport[prisonReport.Year == 2015]
pr2015 = pr2015.sort_values(by = 'Countries', ascending = True)
pr2015 = pr2015.set_index('Countries')

pr2016 = prisonReport[prisonReport.Year == 2016]
pr2016 = pr2016.sort_values(by = 'Countries', ascending = True)
pr2016 = pr2016.set_index('Countries')

pr2017 = prisonReport[prisonReport.Year == 2017]
pr2017 = pr2017.sort_values(by = 'Countries', ascending = True)
pr2017 = pr2017.set_index('Countries')

# %%
# %%capture

Asia = []

pr2004_Asia = pr2004[pr2004.Region == 'Asia']
Asia.append(pr2004_Asia)

pr2005_Asia = pr2005[pr2005.Region == 'Asia']
Asia.append(pr2005_Asia)

pr2006_Asia = pr2006[pr2006.Region == 'Asia']
Asia.append(pr2006_Asia)

pr2007_Asia = pr2007[pr2007.Region == 'Asia']
Asia.append(pr2007_Asia)

pr2008_Asia = pr2008[pr2008.Region == 'Asia']
Asia.append(pr2008_Asia)

pr2009_Asia = pr2009[pr2009.Region == 'Asia']
Asia.append(pr2009_Asia)

pr2010_Asia = pr2010[pr2010.Region == 'Asia']
Asia.append(pr2010_Asia)

pr2011_Asia = pr2011[pr2011.Region == 'Asia']
Asia.append(pr2011_Asia)

pr2012_Asia = pr2012[pr2012.Region == 'Asia']
Asia.append(pr2012_Asia)

pr2013_Asia = pr2013[pr2013.Region == 'Asia']
Asia.append(pr2013_Asia)

pr2014_Asia = pr2014[pr2014.Region == 'Asia']
Asia.append(pr2014_Asia)

pr2015_Asia = pr2015[pr2015.Region == 'Asia']
Asia.append(pr2015_Asia)

pr2016_Asia = pr2016[pr2016.Region == 'Asia']
Asia.append(pr2016_Asia)

pr2017_Asia = pr2017[pr2017.Region == 'Asia']
Asia.append(pr2017_Asia)

for year in range(0, len(Asia)):
    ax = Asia[year]['Count'].plot(kind='barh', figsize = (14, 12), fontsize = 16)
    ax.set_xlabel('Prisioneros', fontsize=16)
    ax.set_ylabel('Países', fontsize=16)
    ax.set_title('Conteo de Prisioneros en Países Asiáticos en el año ' + str(years[year]), fontsize = 18)
    plt.savefig('Week4Charts\Asia' + str(years[year]) + 'bar.png', bbox_inches='tight')
    plt.show()
    
    
for year in range(0, len(Asia)):
    
    Asia[year] = Asia[year].sort_values(by = 'Subregion', ascending = True)
    Asia[year] = Asia[year].set_index('Subregion')
    Asia[year] = Asia[year].sum(level = 'Subregion')
    Asia[year] = Asia[year].drop('Year', axis = 1)

    labels = Asia[year].index
    sizes = Asia[year].Count
    explode = (0.4, 0.1, 0.3, 0.3, 0.3)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.pie(sizes, explode = explode, labels = labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')
    ax.legend(Asia[year].Count, title = 'Prisioneros')
    ax.set_title('Conteo de Prisioneros en Regiones Asiáticas en el año ' + str(years[year]), fontsize = 14)
    plt.savefig('Week4Charts\Asia' + str(years[year]) + 'pie.png', bbox_inches='tight')

# %%
# %%capture

Europe = []

pr2004_Europe = pr2004[pr2004.Region == 'Europe']
Europe.append(pr2004_Europe)

pr2005_Europe = pr2005[pr2005.Region == 'Europe']
Europe.append(pr2005_Europe)

pr2006_Europe = pr2006[pr2006.Region == 'Europe']
Europe.append(pr2006_Europe)

pr2007_Europe = pr2007[pr2007.Region == 'Europe']
Europe.append(pr2007_Europe)

pr2008_Europe = pr2008[pr2008.Region == 'Europe']
Europe.append(pr2008_Europe)

pr2009_Europe = pr2009[pr2009.Region == 'Europe']
Europe.append(pr2009_Europe)

pr2010_Europe = pr2010[pr2010.Region == 'Europe']
Europe.append(pr2010_Europe)

pr2011_Europe = pr2011[pr2011.Region == 'Europe']
Europe.append(pr2011_Europe)

pr2012_Europe = pr2012[pr2012.Region == 'Europe']
Europe.append(pr2012_Europe)

pr2013_Europe = pr2013[pr2013.Region == 'Europe']
Europe.append(pr2013_Europe)

pr2014_Europe = pr2014[pr2014.Region == 'Europe']
Europe.append(pr2014_Europe)

pr2015_Europe = pr2015[pr2015.Region == 'Europe']
Europe.append(pr2015_Europe)

pr2016_Europe = pr2016[pr2016.Region == 'Europe']
Europe.append(pr2016_Europe)

pr2017_Europe = pr2017[pr2017.Region == 'Europe']
Europe.append(pr2017_Europe)

for year in range(0, len(Europe)):
    ax = Europe[year]['Count'].plot(kind='barh', figsize = (14, 12), fontsize = 16)
    ax.set_xlabel('Prisioneros', fontsize=16)
    ax.set_ylabel('Países', fontsize=16)
    ax.set_title('Conteo de Prisioneros en Países Europeos en el año ' + str(years[year]), fontsize = 18)
    plt.savefig('Week4Charts\Euro' + str(years[year]) + 'bar.png', bbox_inches='tight')
    plt.show()
    
    
for year in range(0, len(Europe)):
    
    Europe[year] = Europe[year].sort_values(by = 'Subregion', ascending = True)
    Europe[year] = Europe[year].set_index('Subregion')
    Europe[year] = Europe[year].sum(level = 'Subregion')
    Europe[year] = Europe[year].drop('Year', axis = 1)

    labels = Europe[year].index
    sizes = Europe[year].Count
    explode = (0.1, 0.1, 0.1, 0.1)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.pie(sizes, explode = explode, labels = labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')
    ax.legend(Europe[year].Count, title = 'Prisioneros')
    ax.set_title('Conteo de Prisioneros en Regiones Europeas en el año ' + str(years[year]), fontsize = 14)
    plt.savefig('Week4Charts\Euro' + str(years[year]) + 'pie.png', bbox_inches='tight')

# %%
# %%capture

Africa = []

pr2004_Africa = pr2004[pr2004.Region == 'Africa']
Africa.append(pr2004_Africa)

pr2005_Africa = pr2005[pr2005.Region == 'Africa']
Africa.append(pr2005_Africa)

pr2006_Africa = pr2006[pr2006.Region == 'Africa']
Africa.append(pr2006_Africa)

pr2007_Africa = pr2007[pr2007.Region == 'Africa']
Africa.append(pr2007_Africa)

pr2008_Africa = pr2008[pr2008.Region == 'Africa']
Africa.append(pr2008_Africa)

pr2009_Africa = pr2009[pr2009.Region == 'Africa']
Africa.append(pr2009_Africa)

pr2010_Africa = pr2010[pr2010.Region == 'Africa']
Africa.append(pr2010_Africa)

pr2011_Africa = pr2011[pr2011.Region == 'Africa']
Africa.append(pr2011_Africa)

pr2012_Africa = pr2012[pr2012.Region == 'Africa']
Africa.append(pr2012_Africa)

pr2013_Africa = pr2013[pr2013.Region == 'Africa']
Africa.append(pr2013_Africa)

pr2014_Africa = pr2014[pr2014.Region == 'Africa']
Africa.append(pr2014_Africa)

pr2015_Africa = pr2015[pr2015.Region == 'Africa']
Africa.append(pr2015_Africa)

pr2016_Africa = pr2016[pr2016.Region == 'Africa']
Africa.append(pr2016_Africa)

pr2017_Africa = pr2017[pr2017.Region == 'Africa']
Africa.append(pr2017_Africa)

for year in range(0, len(Africa)):
    ax = Africa[year]['Count'].plot(kind='barh', figsize = (14, 12), fontsize = 16)
    ax.set_xlabel('Prisioneros', fontsize=16)
    ax.set_ylabel('Países', fontsize=16)
    ax.set_title('Conteo de Prisioneros en Países Africanos en el año ' + str(years[year]), fontsize = 18)
    plt.savefig('Week4Charts\Africa' + str(years[year]) + 'bar.png', bbox_inches='tight')
    plt.show()
    
    
for year in range(0, len(Africa)):
    
    Africa[year] = Africa[year].sort_values(by = 'Subregion', ascending = True)
    Africa[year] = Africa[year].set_index('Subregion')
    Africa[year] = Africa[year].sum(level = 'Subregion')
    Africa[year] = Africa[year].drop('Year', axis = 1)

    labels = Africa[year].index
    sizes = Africa[year].Count

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.pie(sizes, labels = labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')
    ax.legend(Africa[year].Count, title = 'Prisioneros')
    ax.set_title('Conteo de Prisioneros en Regiones Africanas en el año ' + str(years[year]), fontsize = 14)
    plt.savefig('Week4Charts\Africa' + str(years[year]) + 'pie.png', bbox_inches='tight')

# %%
# %%capture

Oceania = []

pr2004_Oceania = pr2004[pr2004.Region == 'Oceania']
Oceania.append(pr2004_Oceania)

pr2005_Oceania = pr2005[pr2005.Region == 'Oceania']
Oceania.append(pr2005_Oceania)

pr2006_Oceania = pr2006[pr2006.Region == 'Oceania']
Oceania.append(pr2006_Oceania)

pr2007_Oceania = pr2007[pr2007.Region == 'Oceania']
Oceania.append(pr2007_Oceania)

pr2008_Oceania = pr2008[pr2008.Region == 'Oceania']
Oceania.append(pr2008_Oceania)

pr2009_Oceania = pr2009[pr2009.Region == 'Oceania']
Oceania.append(pr2009_Oceania)

pr2010_Oceania = pr2010[pr2010.Region == 'Oceania']
Oceania.append(pr2010_Oceania)

pr2011_Oceania = pr2011[pr2011.Region == 'Oceania']
Oceania.append(pr2011_Oceania)

pr2012_Oceania = pr2012[pr2012.Region == 'Oceania']
Oceania.append(pr2012_Oceania)

pr2013_Oceania = pr2013[pr2013.Region == 'Oceania']
Oceania.append(pr2013_Oceania)

pr2014_Oceania = pr2014[pr2014.Region == 'Oceania']
Oceania.append(pr2014_Oceania)

pr2015_Oceania = pr2015[pr2015.Region == 'Oceania']
Oceania.append(pr2015_Oceania)

pr2016_Oceania = pr2016[pr2016.Region == 'Oceania']
Oceania.append(pr2016_Oceania)

pr2017_Oceania = pr2017[pr2017.Region == 'Oceania']
Oceania.append(pr2017_Oceania)

for year in range(0, len(Oceania)):
    ax = Oceania[year]['Count'].plot(kind='barh', figsize = (14, 12), fontsize = 16)
    ax.set_xlabel('Prisioneros', fontsize=16)
    ax.set_ylabel('Países', fontsize=16)
    ax.set_title('Conteo de Prisioneros en Países Oceánicos en el año ' + str(years[year]), fontsize = 18)
    plt.savefig('Week4Charts\Oceania' + str(years[year]) + 'bar.png', bbox_inches='tight')
    plt.show()
    
    
for year in range(0, len(Oceania)):
    
    Oceania[year] = Oceania[year].sort_values(by = 'Subregion', ascending = True)
    Oceania[year] = Oceania[year].set_index('Subregion')
    Oceania[year] = Oceania[year].sum(level = 'Subregion')
    Oceania[year] = Oceania[year].drop('Year', axis = 1)

    labels = Oceania[year].index
    sizes = Oceania[year].Count
    
    if(years[year] == 2013): explode = (0.1, 0.55, 0.55)
        
    else: explode = (0.1, 0.55, 0.55, 0.55)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.pie(sizes, explode = explode, labels = labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')
    ax.legend(Oceania[year].Count, title = 'Prisioneros')
    ax.set_title('Conteo de Prisioneros en Regiones Oceánicas en el año ' + str(years[year]), fontsize = 14)
    plt.savefig('Week4Charts\Oceania' + str(years[year]) + 'pie.png', bbox_inches='tight')

# %%
# %%capture

Americas = []

pr2004_Americas = pr2004[pr2004.Region == 'Americas']
Americas.append(pr2004_Americas)

pr2005_Americas = pr2005[pr2005.Region == 'Americas']
Americas.append(pr2005_Americas)

pr2006_Americas = pr2006[pr2006.Region == 'Americas']
Americas.append(pr2006_Americas)

pr2007_Americas = pr2007[pr2007.Region == 'Americas']
Americas.append(pr2007_Americas)

pr2008_Americas = pr2008[pr2008.Region == 'Americas']
Americas.append(pr2008_Americas)

pr2009_Americas = pr2009[pr2009.Region == 'Americas']
Americas.append(pr2009_Americas)

pr2010_Americas = pr2010[pr2010.Region == 'Americas']
Americas.append(pr2010_Americas)

pr2011_Americas = pr2011[pr2011.Region == 'Americas']
Americas.append(pr2011_Americas)

pr2012_Americas = pr2012[pr2012.Region == 'Americas']
Americas.append(pr2012_Americas)

pr2013_Americas = pr2013[pr2013.Region == 'Americas']
Americas.append(pr2013_Americas)

pr2014_Americas = pr2014[pr2014.Region == 'Americas']
Americas.append(pr2014_Americas)

pr2015_Americas = pr2015[pr2015.Region == 'Americas']
Americas.append(pr2015_Americas)

pr2016_Americas = pr2016[pr2016.Region == 'Americas']
Americas.append(pr2016_Americas)

pr2017_Americas = pr2017[pr2017.Region == 'Americas']
Americas.append(pr2017_Americas)

for year in range(0, len(Americas)):
    ax = Americas[year]['Count'].plot(kind='barh', figsize = (14, 12), fontsize = 16)
    ax.set_xlabel('Prisioneros', fontsize=16)
    ax.set_ylabel('Países', fontsize=16)
    ax.set_title('Conteo de Prisioneros en Países Americanos en el año ' + str(years[year]), fontsize = 18)
    plt.savefig('Week4Charts\Ame' + str(years[year]) + 'bar.png', bbox_inches='tight')
    plt.show()
    
    
for year in range(0, len(Americas)):
    
    Americas[year] = Americas[year].sort_values(by = 'Subregion', ascending = True)
    Americas[year] = Americas[year].set_index('Subregion')
    Americas[year] = Americas[year].sum(level = 'Subregion')
    Americas[year] = Americas[year].drop('Year', axis = 1)

    labels = Americas[year].index
    sizes = Americas[year].Count
    explode = (0.5, 0.1, 0.1, 0.1)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.pie(sizes, explode = explode, labels = labels, autopct='%1.1f%%',
            shadow=True, startangle=90)
    ax.axis('equal')
    ax.legend(Americas[year].Count, title = 'Prisioneros')
    ax.set_title('Conteo de Prisioneros en Regiones Americanas en el año ' + str(years[year]), fontsize = 14)
    plt.savefig('Week4Charts\Ame' + str(years[year]) + 'pie.png', bbox_inches='tight')

# %% [markdown]
# # Evolución anual de la cantidad de prisioneros en los países con más prisioneros

# %%
China, SouthAfrica, Usa, Russia, Australia = [], [], [], [], []

China.append(pr2004_Asia.loc['China'].Count)
China.append(pr2005_Asia.loc['China'].Count)
China.append(pr2006_Asia.loc['China'].Count)
China.append(pr2008_Asia.loc['China'].Count)
China.append(pr2009_Asia.loc['China'].Count)
China.append(pr2009_Asia.loc['China'].Count)
China.append(pr2010_Asia.loc['China'].Count)
China.append(pr2011_Asia.loc['China'].Count)
China.append(pr2012_Asia.loc['China'].Count)
China.append(pr2013_Asia.loc['China'].Count)
China.append(pr2014_Asia.loc['China'].Count)
China.append(pr2015_Asia.loc['China'].Count)
China.append(pr2016_Asia.loc['China'].Count)
China.append(np.nan)

SouthAfrica.append(pr2004_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2005_Africa.loc['South Africa'].Count)
SouthAfrica.append(np.nan)
SouthAfrica.append(np.nan)
SouthAfrica.append(pr2008_Africa.loc['South Africa'].Count)
SouthAfrica.append(np.nan)
SouthAfrica.append(pr2010_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2011_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2012_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2013_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2014_Africa.loc['South Africa'].Count)
SouthAfrica.append(pr2015_Africa.loc['South Africa'].Count)
SouthAfrica.append(np.nan)
SouthAfrica.append(pr2017_Africa.loc['South Africa'].Count)

Usa.append(pr2004_Americas.loc['United States of America'].Count)
Usa.append(pr2005_Americas.loc['United States of America'].Count)
Usa.append(pr2006_Americas.loc['United States of America'].Count)
Usa.append(pr2007_Americas.loc['United States of America'].Count)
Usa.append(pr2008_Americas.loc['United States of America'].Count)
Usa.append(pr2009_Americas.loc['United States of America'].Count)
Usa.append(pr2010_Americas.loc['United States of America'].Count)
Usa.append(pr2011_Americas.loc['United States of America'].Count)
Usa.append(pr2012_Americas.loc['United States of America'].Count)
Usa.append(pr2013_Americas.loc['United States of America'].Count)
Usa.append(pr2014_Americas.loc['United States of America'].Count)
Usa.append(pr2015_Americas.loc['United States of America'].Count)
Usa.append(pr2016_Americas.loc['United States of America'].Count)
Usa.append(np.nan)

Russia.append(pr2004_Europe.loc['Russian Federation'].Count)
Russia.append(pr2005_Europe.loc['Russian Federation'].Count)
Russia.append(pr2006_Europe.loc['Russian Federation'].Count)
Russia.append(pr2007_Europe.loc['Russian Federation'].Count)
Russia.append(pr2008_Europe.loc['Russian Federation'].Count)
Russia.append(pr2009_Europe.loc['Russian Federation'].Count)
Russia.append(pr2010_Europe.loc['Russian Federation'].Count)
Russia.append(pr2011_Europe.loc['Russian Federation'].Count)
Russia.append(pr2012_Europe.loc['Russian Federation'].Count)
Russia.append(pr2013_Europe.loc['Russian Federation'].Count)
Russia.append(pr2014_Europe.loc['Russian Federation'].Count)
Russia.append(pr2015_Europe.loc['Russian Federation'].Count)
Russia.append(pr2016_Europe.loc['Russian Federation'].Count)
Russia.append(pr2017_Europe.loc['Russian Federation'].Count)

Australia.append(pr2004_Oceania.loc['Australia'].Count)
Australia.append(np.nan)
Australia.append(np.nan)
Australia.append(pr2007_Oceania.loc['Australia'].Count)
Australia.append(pr2008_Oceania.loc['Australia'].Count)
Australia.append(pr2009_Oceania.loc['Australia'].Count)
Australia.append(pr2010_Oceania.loc['Australia'].Count)
Australia.append(pr2011_Oceania.loc['Australia'].Count)
Australia.append(pr2012_Oceania.loc['Australia'].Count)
Australia.append(pr2013_Oceania.loc['Australia'].Count)
Australia.append(pr2014_Oceania.loc['Australia'].Count)
Australia.append(pr2015_Oceania.loc['Australia'].Count)
Australia.append(pr2016_Oceania.loc['Australia'].Count)
Australia.append(pr2017_Oceania.loc['Australia'].Count)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

width =0.3
plt.bar(years, China, width = width, label = 'China')
plt.bar(years + width, Usa, width = width, label = 'U.S.A.')
plt.bar(years + 2*width, SouthAfrica, width = width, label = 'S. Africa')
plt.bar(years + width, Russia, width = width, label = 'Russia')
plt.bar(years, Australia, width = width, label = 'Australia')

plt.xlabel('Año', fontsize = 16)
plt.ylabel('Prisioneros', fontsize = 16)
plt.title('Países con el Mayor Número de Prisioneros', fontsize = 16)
plt.xticks(years + 0.8*width, years)
plt.legend(loc = 'center right')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()

# %%
AfricaCount, AmerCount, AsiaCount, EuroCount, OceaCount = [], [], [], [], [] 

AfricaCount.append(pr2004_Africa.sum().Count)
AfricaCount.append(pr2005_Africa.sum().Count)
AfricaCount.append(pr2006_Africa.sum().Count)
AfricaCount.append(pr2007_Africa.sum().Count)
AfricaCount.append(pr2008_Africa.sum().Count)
AfricaCount.append(pr2009_Africa.sum().Count)
AfricaCount.append(pr2010_Africa.sum().Count)
AfricaCount.append(pr2011_Africa.sum().Count)
AfricaCount.append(pr2012_Africa.sum().Count)
AfricaCount.append(pr2013_Africa.sum().Count)
AfricaCount.append(pr2014_Africa.sum().Count)
AfricaCount.append(pr2015_Africa.sum().Count)
AfricaCount.append(pr2016_Africa.sum().Count)
AfricaCount.append(pr2017_Africa.sum().Count)

AmerCount.append(pr2004_Americas.sum().Count)
AmerCount.append(pr2005_Americas.sum().Count)
AmerCount.append(pr2006_Americas.sum().Count)
AmerCount.append(pr2007_Americas.sum().Count)
AmerCount.append(pr2008_Americas.sum().Count)
AmerCount.append(pr2009_Americas.sum().Count)
AmerCount.append(pr2010_Americas.sum().Count)
AmerCount.append(pr2011_Americas.sum().Count)
AmerCount.append(pr2012_Americas.sum().Count)
AmerCount.append(pr2013_Americas.sum().Count)
AmerCount.append(pr2014_Americas.sum().Count)
AmerCount.append(pr2015_Americas.sum().Count)
AmerCount.append(pr2016_Americas.sum().Count)
AmerCount.append(pr2017_Americas.sum().Count)

AsiaCount.append(pr2004_Asia.sum().Count)
AsiaCount.append(pr2005_Asia.sum().Count)
AsiaCount.append(pr2006_Asia.sum().Count)
AsiaCount.append(pr2007_Asia.sum().Count)
AsiaCount.append(pr2008_Asia.sum().Count)
AsiaCount.append(pr2009_Asia.sum().Count)
AsiaCount.append(pr2010_Asia.sum().Count)
AsiaCount.append(pr2011_Asia.sum().Count)
AsiaCount.append(pr2012_Asia.sum().Count)
AsiaCount.append(pr2013_Asia.sum().Count)
AsiaCount.append(pr2014_Asia.sum().Count)
AsiaCount.append(pr2015_Asia.sum().Count)
AsiaCount.append(pr2016_Asia.sum().Count)
AsiaCount.append(pr2017_Asia.sum().Count)

EuroCount.append(pr2004_Europe.sum().Count)
EuroCount.append(pr2005_Europe.sum().Count)
EuroCount.append(pr2006_Europe.sum().Count)
EuroCount.append(pr2007_Europe.sum().Count)
EuroCount.append(pr2008_Europe.sum().Count)
EuroCount.append(pr2009_Europe.sum().Count)
EuroCount.append(pr2010_Europe.sum().Count)
EuroCount.append(pr2011_Europe.sum().Count)
EuroCount.append(pr2012_Europe.sum().Count)
EuroCount.append(pr2013_Europe.sum().Count)
EuroCount.append(pr2014_Europe.sum().Count)
EuroCount.append(pr2015_Europe.sum().Count)
EuroCount.append(pr2016_Europe.sum().Count)
EuroCount.append(pr2017_Europe.sum().Count)

OceaCount.append(pr2004_Oceania.sum().Count)
OceaCount.append(pr2005_Oceania.sum().Count)
OceaCount.append(pr2006_Oceania.sum().Count)
OceaCount.append(pr2007_Oceania.sum().Count)
OceaCount.append(pr2008_Oceania.sum().Count)
OceaCount.append(pr2009_Oceania.sum().Count)
OceaCount.append(pr2010_Oceania.sum().Count)
OceaCount.append(pr2011_Oceania.sum().Count)
OceaCount.append(pr2012_Oceania.sum().Count)
OceaCount.append(pr2013_Oceania.sum().Count)
OceaCount.append(pr2014_Oceania.sum().Count)
OceaCount.append(pr2015_Oceania.sum().Count)
OceaCount.append(pr2016_Oceania.sum().Count)
OceaCount.append(pr2017_Oceania.sum().Count)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

width =0.3
plt.bar(years, AfricaCount, width = width, label = 'África')
plt.bar(years + width, AmerCount, width = width, label = 'América')
plt.bar(years + 2*width, AsiaCount, width = width, label = 'Asia')
plt.bar(years + width, EuroCount, width = width, label = 'Europa')
plt.bar(years, OceaCount, width = width, label = 'Oceanía')

plt.xlabel('Año', fontsize = 16)
plt.ylabel('Prisioneros', fontsize = 16)
plt.title('Continentes con el Mayor Número de Prisioneros', fontsize = 16)
plt.xticks(years + 0.8*width, years)
plt.legend(loc = 'center left')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.show()
