# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
          'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

# %%
rainEne2018 = pd.read_csv('201801010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainFeb2018 = pd.read_csv('201802010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainMar2018 = pd.read_csv('201803010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainAbr2018 = pd.read_csv('201804010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainMay2018 = pd.read_csv('201805010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainJun2018 = pd.read_csv('201806010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainJul2018 = pd.read_csv('201807010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainAgo2018 = pd.read_csv('201808010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainOct2018 = pd.read_csv('201810010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainNov2018 = pd.read_csv('201811010000Lluv.csv', usecols = (4,5), encoding='latin-1')

# %%
rainEne2019 = pd.read_csv('201801010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainFeb2019 = pd.read_csv('201802010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainMar2019 = pd.read_csv('201903010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainAbr2019 = pd.read_csv('201904010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainMay2019 = pd.read_csv('201905010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainJun2019 = pd.read_csv('201906010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainJul2019 = pd.read_csv('201907010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainAgo2019 = pd.read_csv('201908010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainOct2019 = pd.read_csv('201910010000Lluv.csv', usecols = (4,5), encoding='latin-1')
rainNov2019 = pd.read_csv('201911010000Lluv.csv', usecols = (4,5), encoding='latin-1')

# %%
rainData2018 = pd.merge(rainEne2018, rainFeb2018)
rainData2018 = pd.merge(rainData2018, rainMar2018)
rainData2018 = pd.merge(rainData2018, rainAbr2018)
rainData2018 = pd.merge(rainData2018, rainMay2018)
rainData2018 = pd.merge(rainData2018, rainJun2018)
rainData2018 = pd.merge(rainData2018, rainJul2018)
rainData2018 = pd.merge(rainData2018, rainAgo2018)
rainData2018 = pd.merge(rainData2018, rainSep2018)
rainData2018 = pd.merge(rainData2018, rainOct2018)
rainData2018 = pd.merge(rainData2018, rainNov2018)
rainData2018
# Out:
#                                            NOMBRE   ENE   FEB   MAR    ABR  \
# 0                            Aguascalientes, Ags.  25.8  28.7  0.00    0.0
# 1                     Cincuenta Aniversario, Ags.  58.6  24.4  0.00    2.6
# 2                             Calvillo, Ags. SMN*  56.0  19.5  0.00    5.3
# 3                               La Codorniz, Ags.  50.0  30.0  0.00    0.0
# 4                                 Los Conos, Ags.  51.5  33.0  0.01  106.3
# ...                                           ...   ...   ...   ...    ...
# 3728                             Sombrerete, Zac.   8.2  20.9  0.30    3.5
# 3729  Santa Teresa (Independencia Nacional), Zac.  27.9  17.1  0.00    1.0
# 3730                             Santa Rosa, Zac.  25.5  53.0  0.01    0.0
# 3731                          Chalchihuites, Zac.   6.0  22.0  0.00    1.0
# 3732                              Zacatecas, Zac.  43.3  18.0  0.00    3.0
#
#        MAY     JUN    JUL    AGO     SEP     OCT    NOV
# ...

# %%
rainData2019 = pd.merge(rainEne2019, rainFeb2019)
rainData2019 = pd.merge(rainData2019, rainMar2019)
rainData2019 = pd.merge(rainData2019, rainAbr2019)
rainData2019 = pd.merge(rainData2019, rainMay2019)
rainData2019 = pd.merge(rainData2019, rainJun2019)

rainJul2019 = rainJul2019.rename(columns = {'ESTACION': 'NOMBRE'})
rainData2019 = pd.merge(rainData2019, rainJul2019)

rainAgo2019 = rainAgo2019.rename(columns = {'ESTACION': 'NOMBRE'})
rainData2019 = pd.merge(rainData2019, rainAgo2019)

rainSep2019 = rainSep2019.rename(columns = {'ESTACION': 'NOMBRE'})
rainData2019 = pd.merge(rainData2019, rainSep2019)

rainOct2019 = rainOct2019.rename(columns = {'ESTACION': 'NOMBRE'})
rainData2019 = pd.merge(rainData2019, rainOct2019)

rainNov2019 = rainNov2019.rename(columns = {'ESTACION': 'NOMBRE'})
rainData2019 = pd.merge(rainData2019, rainNov2019)

rainData2019
# Out:
#                                            NOMBRE   ENE   FEB   MAR   ABR  \
# 0                             Calvillo, Ags. SMN*  56.0  19.5  0.00  0.00
# 1                               La Codorniz, Ags.  50.0  30.0  0.00  0.00
# 2                                 Los Conos, Ags.  51.5  33.0  2.31  0.00
# 3                                Media Luna, Ags.  48.9  32.7  0.00  0.00
# 4                                El Niagara, Ags.  25.4  41.1  0.00  0.00
# ...                                           ...   ...   ...   ...   ...
# 3691                          San Francisco, Zac.   9.7   9.0  2.01  0.01
# 3692                             Sombrerete, Zac.   8.2  20.9  0.50  0.00
# 3693  Santa Teresa (Independencia Nacional), Zac.  27.9  17.1  0.01  0.00
# 3694                             Santa Rosa, Zac.  25.5  53.0  0.01  0.00
# 3695                          Chalchihuites, Zac.   6.0  22.0  0.00  0.00
#
#        MAY     JUN    JUL     AGO     SEP  oct-19  nov-19
# ...

# %%
rainData2018.append(rainData2019)
rainData2018
# Out:
#                                            NOMBRE   ENE   FEB   MAR    ABR  \
# 0                            Aguascalientes, Ags.  25.8  28.7  0.00    0.0
# 1                     Cincuenta Aniversario, Ags.  58.6  24.4  0.00    2.6
# 2                             Calvillo, Ags. SMN*  56.0  19.5  0.00    5.3
# 3                               La Codorniz, Ags.  50.0  30.0  0.00    0.0
# 4                                 Los Conos, Ags.  51.5  33.0  0.01  106.3
# ...                                           ...   ...   ...   ...    ...
# 3728                             Sombrerete, Zac.   8.2  20.9  0.30    3.5
# 3729  Santa Teresa (Independencia Nacional), Zac.  27.9  17.1  0.00    1.0
# 3730                             Santa Rosa, Zac.  25.5  53.0  0.01    0.0
# 3731                          Chalchihuites, Zac.   6.0  22.0  0.00    1.0
# 3732                              Zacatecas, Zac.  43.3  18.0  0.00    3.0
#
#        MAY     JUN    JUL    AGO     SEP     OCT    NOV
# ...

# %%
tmaxEne2018 = pd.read_csv('201801010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxFeb2018 = pd.read_csv('201802010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxMar2018 = pd.read_csv('201803010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxAbr2018 = pd.read_csv('201804010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxMay2018 = pd.read_csv('201805010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxJun2018 = pd.read_csv('201806010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxJul2018 = pd.read_csv('201807010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxAgo2018 = pd.read_csv('201808010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxOct2018 = pd.read_csv('201810010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxNov2018 = pd.read_csv('201811010000TMax.csv', usecols = (4,5), encoding='latin-1')

# %%
tmaxEne2019 = pd.read_csv('201801010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxFeb2019 = pd.read_csv('201802010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxMar2019 = pd.read_csv('201903010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxAbr2019 = pd.read_csv('201904010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxMay2019 = pd.read_csv('201905010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxJun2019 = pd.read_csv('201906010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxJul2019 = pd.read_csv('201907010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxAgo2019 = pd.read_csv('201908010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxOct2019 = pd.read_csv('201910010000TMax.csv', usecols = (4,5), encoding='latin-1')
tmaxNov2019 = pd.read_csv('201911010000TMax.csv', usecols = (4,5), encoding='latin-1')

# %%
tminEne2018 = pd.read_csv('201801010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminFeb2018 = pd.read_csv('201802010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminMar2018 = pd.read_csv('201803010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminAbr2018 = pd.read_csv('201804010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminMay2018 = pd.read_csv('201805010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminJun2018 = pd.read_csv('201806010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminJul2018 = pd.read_csv('201807010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminAgo2018 = pd.read_csv('201808010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminOct2018 = pd.read_csv('201810010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminNov2018 = pd.read_csv('201811010000TMin.csv', usecols = (4,5), encoding='latin-1')

# %%
tminEne2019 = pd.read_csv('201901010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminFeb2019 = pd.read_csv('201902010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminMar2019 = pd.read_csv('201903010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminAbr2019 = pd.read_csv('201904010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminMay2019 = pd.read_csv('201905010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminJun2019 = pd.read_csv('201906010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminJul2019 = pd.read_csv('201907010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminAgo2019 = pd.read_csv('201908010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminOct2019 = pd.read_csv('201910010000TMin.csv', usecols = (4,5), encoding='latin-1')
tminNov2019 = pd.read_csv('201911010000TMin.csv', usecols = (4,5), encoding='latin-1')
